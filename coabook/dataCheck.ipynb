# %% [markdown]
# <a href="https://colab.research.google.com/github/coa-project/pycoa/blob/main/coabook/dataCheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/coa-project/pycoa/zenodo-backup)

# %% [markdown]
# # Data Check for Pycoa [ⓒpycoa.fr](http://pycoa.fr) <img src="https://www.pycoa.fr/fig/logo-anime.gif" alt="Pycoa" width="35">

# %% [markdown]
# ## Importing packages

# %% [markdown]
# The following commands ensure that Pycoa is correctly installed and configured:
# * for local installation
# * for use in Colab
# * for use in Binder
#
# **Execute these lines without asking too many questions...**

# %%
import sys
import subprocess
import importlib
coa_module_info = importlib.util.find_spec("coaenv")
if coa_module_info != None:
  import coaenv as pycoa
else:
  #dans le cas où on utilise colab de Google  
  subprocess.check_call(['pip3', 'install', '--quiet', 'git+https://github.com/coa-project/pycoa.git@ReadingDataModification'])
  sys.path.insert(1, 'pycoa')
  # !pip install pandas==1.4.2
  import coa.front as pycoa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas==1.4.2 in /home/mxrtinez/.local/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from pandas==1.4.2) (1.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.16.0)

# %% [markdown]
# ## Select the database

# %% [markdown]
# First select the database to get the data. For this use `pycoa.setwhom("DataBase")` replacing `DataBase` with the any of the databases in `pycoa.listwhom(True)`.
#
# >If no epidemiological database is selected with `pycoa.setwhom`, the `JHU` database for John Hopkins University is loaded by default. JHU was one of the first institutions to aggregate epidemiological data from countries, and to offer a web-based dashboard to view the data: https://coronavirus.jhu.edu/map.html.
#
# PyCoA was designed to extend the possibilities of these *dashboards*. On the one hand, it allows you to retrieve epidemiological data directly; on the other, it allows you to display the data as you wish.

# %%
pycoa.setwhom("jhu",reload=False)
# Out:
# Info of jhu stored
# last update: Thu Nov 16 16:09:55 2023
# Few information concernant the selected database :  jhu
# Available key-words, which ∈ ['tot_confirmed', 'tot_deaths', 'tot_recovered']
# Example of where :  Turkey, Bhutan, Congo, Zambia, Egypt  ...
# Last date data  2023-03-09

# %% [markdown]
# ## Pycoa instructions

# %% [markdown]
# * `pycoa.plot`: for time series
# * `pycoa.map`: for a map representation
# * `pycoa.hist`: for histograms, with the following options
#   * `typeofhist='bycountry'` (default), for a histogram with horizontal bars, location by location
#   * `typeofhist='byvalue'`, for a histogram with vertical bars, by value
#   * `typeofhist='pie'`, for a pie chart
# * `pycoa.get`: to retrieve data for further processing

# %% [markdown]
# ### Documentation

# %% [markdown]
# A more complete documentation of Pycoa instructions and options can be found on the [Pycoa wiki](https://github.com/coa-project/pycoa/wiki/Accueil). In particular, see the menu at the bottom right:
# * [Data retrieval and processing](https://github.com/coa-project/pycoa/wiki/Donn%C3%A9es%2Ctraitements)
# * [Curve graphs](https://github.com/coa-project/pycoa/wiki/Courbes)
# * [Histograms, sectors and maps](https://github.com/coa-project/pycoa/wiki/Diagrammes%2CCartes)
# * [Advanced](https://github.com/coa-project/pycoa/wiki/Avance)
# * [Case studies](https://github.com/coa-project/pycoa/wiki/Etudes%2Cde%2Ccas)

# %% [markdown]
# ### *Keywords*

# %% [markdown]
# Different keywords are possible for the various instructions:
#
# * `which`: data selected from the current database.
# * `what`: cumulative, daily or weekly information.
# * `where`: selection of the location, depending on the database used.
#   * country, list of countries, regions, continents, etc.
#   * department, list of departments, regions.
# * `option`: "nonneg", "nofillnan", "smooth7", "sumall".
# * `when`: date window for selected data.
#
# You can use the following functions to get all available configurations `pycoa.listwhich()` `pycoa.listwhat()` `pycoa.listoption()` `pycoa.listwhere()`

# %% [markdown]
# # Use the databases

# %% [markdown]
# List available databases

# %%
pycoa.listwhom(True)
# Out:
# Pandas has been pimped, use '.data' to get a pandas dataframe
# <style type="text/css">
# #T_2a8f1_  {
#   border: 3px solid green;
# }
# </style>
# <table id="T_2a8f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Database</th>
#       <th class="col_heading level0 col1" >WW/iso3</th>
#       <th class="col_heading level0 col2" >Granularité</th>
#       <th class="col_heading level0 col3" >WW/Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a8f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a8f1_row0_col0" class="data row0 col0" >dgs</td>
#       <td id="T_2a8f1_row0_col1" class="data row0 col1" >PRT</td>
#       <td id="T_2a8f1_row0_col2" class="data row0 col2" >region</td>
#       <td id="T_2a8f1_row0_col3" class="data row0 col3" >Portugal</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a8f1_row1_col0" class="data row1 col0" >dpc</td>
#       <td id="T_2a8f1_row1_col1" class="data row1 col1" >ITA</td>
#       <td id="T_2a8f1_row1_col2" class="data row1 col2" >region</td>
#       <td id="T_2a8f1_row1_col3" class="data row1 col3" >Italy</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2a8f1_row2_col0" class="data row2 col0" >escovid19data</td>
#       <td id="T_2a8f1_row2_col1" class="data row2 col1" >ESP</td>
#       <td id="T_2a8f1_row2_col2" class="data row2 col2" >subregion</td>
#       <td id="T_2a8f1_row2_col3" class="data row2 col3" >Spain</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2a8f1_row3_col0" class="data row3 col0" >europa</td>
#       <td id="T_2a8f1_row3_col1" class="data row3 col1" >WW</td>
#       <td id="T_2a8f1_row3_col2" class="data row3 col2" >nation</td>
#       <td id="T_2a8f1_row3_col3" class="data row3 col3" >Europe</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2a8f1_row4_col0" class="data row4 col0" >govcy</td>
#       <td id="T_2a8f1_row4_col1" class="data row4 col1" >CYP</td>
#       <td id="T_2a8f1_row4_col2" class="data row4 col2" >nation</td>
#       <td id="T_2a8f1_row4_col3" class="data row4 col3" >Cyprus</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2a8f1_row5_col0" class="data row5 col0" >imed</td>
#       <td id="T_2a8f1_row5_col1" class="data row5 col1" >GRC</td>
#       <td id="T_2a8f1_row5_col2" class="data row5 col2" >region</td>
#       <td id="T_2a8f1_row5_col3" class="data row5 col3" >Greece</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2a8f1_row6_col0" class="data row6 col0" >insee</td>
#       <td id="T_2a8f1_row6_col1" class="data row6 col1" >FRA</td>
#       <td id="T_2a8f1_row6_col2" class="data row6 col2" >subregion</td>
#       <td id="T_2a8f1_row6_col3" class="data row6 col3" >France</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2a8f1_row7_col0" class="data row7 col0" >jhu</td>
#       <td id="T_2a8f1_row7_col1" class="data row7 col1" >WW</td>
#       <td id="T_2a8f1_row7_col2" class="data row7 col2" >nation</td>
#       <td id="T_2a8f1_row7_col3" class="data row7 col3" >World</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2a8f1_row8_col0" class="data row8 col0" >jhu-usa</td>
#       <td id="T_2a8f1_row8_col1" class="data row8 col1" >USA</td>
#       <td id="T_2a8f1_row8_col2" class="data row8 col2" >subregion</td>
#       <td id="T_2a8f1_row8_col3" class="data row8 col3" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2a8f1_row9_col0" class="data row9 col0" >jpnmhlw</td>
#       <td id="T_2a8f1_row9_col1" class="data row9 col1" >JPN</td>
#       <td id="T_2a8f1_row9_col2" class="data row9 col2" >subregion</td>
#       <td id="T_2a8f1_row9_col3" class="data row9 col3" >Japan</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2a8f1_row10_col0" class="data row10 col0" >moh</td>
#       <td id="T_2a8f1_row10_col1" class="data row10 col1" >MYS</td>
#       <td id="T_2a8f1_row10_col2" class="data row10 col2" >subregion</td>
#       <td id="T_2a8f1_row10_col3" class="data row10 col3" >Malaysia</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2a8f1_row11_col0" class="data row11 col0" >mpoxgh</td>
#       <td id="T_2a8f1_row11_col1" class="data row11 col1" >WW</td>
#       <td id="T_2a8f1_row11_col2" class="data row11 col2" >nation</td>
#       <td id="T_2a8f1_row11_col3" class="data row11 col3" >World</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2a8f1_row12_col0" class="data row12 col0" >owid</td>
#       <td id="T_2a8f1_row12_col1" class="data row12 col1" >WW</td>
#       <td id="T_2a8f1_row12_col2" class="data row12 col2" >nation</td>
#       <td id="T_2a8f1_row12_col3" class="data row12 col3" >World</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2a8f1_row13_col0" class="data row13 col0" >phe</td>
#       <td id="T_2a8f1_row13_col1" class="data row13 col1" >GBR</td>
#       <td id="T_2a8f1_row13_col2" class="data row13 col2" >subregion</td>
#       <td id="T_2a8f1_row13_col3" class="data row13 col3" >United Kingdom</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2a8f1_row14_col0" class="data row14 col0" >risklayer</td>
#       <td id="T_2a8f1_row14_col1" class="data row14 col1" >EUR</td>
#       <td id="T_2a8f1_row14_col2" class="data row14 col2" >subregion</td>
#       <td id="T_2a8f1_row14_col3" class="data row14 col3" >Europe</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2a8f1_row15_col0" class="data row15 col0" >rki</td>
#       <td id="T_2a8f1_row15_col1" class="data row15 col1" >DEU</td>
#       <td id="T_2a8f1_row15_col2" class="data row15 col2" >subregion</td>
#       <td id="T_2a8f1_row15_col3" class="data row15 col3" >Germany</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2a8f1_row16_col0" class="data row16 col0" >sciensano</td>
#       <td id="T_2a8f1_row16_col1" class="data row16 col1" >BEL</td>
#       <td id="T_2a8f1_row16_col2" class="data row16 col2" >region</td>
#       <td id="T_2a8f1_row16_col3" class="data row16 col3" >Belgium</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2a8f1_row17_col0" class="data row17 col0" >spf</td>
#       <td id="T_2a8f1_row17_col1" class="data row17 col1" >FRA</td>
#       <td id="T_2a8f1_row17_col2" class="data row17 col2" >subregion</td>
#       <td id="T_2a8f1_row17_col3" class="data row17 col3" >France</td>
#     </tr>
#     <tr>
#       <th id="T_2a8f1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2a8f1_row18_col0" class="data row18 col0" >spfnational</td>
#       <td id="T_2a8f1_row18_col1" class="data row18 col1" >WW</td>
#       <td id="T_2a8f1_row18_col2" class="data row18 col2" >nation</td>
#       <td id="T_2a8f1_row18_col3" class="data row18 col3" >France</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Select 'owid' database

# %%
pycoa.setwhom('insee',reload=False)
# Out:
# Info of insee stored
# last update: Thu Nov 16 16:12:01 2023
# Few information concernant the selected database :  insee
# Available key-words, which ∈ ['tot_deaths_since_2018-01-01']
# Example of where :  Lot, Bas-Rhin, Alpes-Maritimes, Drôme, Territoire de Belfort  ...
# Last date data  2024-04-15

# %%
pycoa.listwhich()
# Out:
# ['tot_deaths_since_2018-01-01']

# %%
pycoa.listwhat()
# Out:
# ['standard', 'daily', 'weekly']

# %%
pycoa.listoption()
# Out:
# ['nonneg', 'nofillnan', 'smooth7', 'sumall']

# %%
pycoa.listwhere()
# Out:
# ['Ain',
#  'Aisne',
#  'Allier',
#  'Alpes-de-Haute-Provence',
#  'Hautes-Alpes',
#  'Alpes-Maritimes',
#  'Ardèche',
#  'Ardennes',
#  'Ariège',
#  'Aube',
#  'Aude',
#  'Aveyron',
#  'Bouches-du-Rhône',
#  'Calvados',
#  'Cantal',
#  'Charente',
#  'Charente-Maritime',
#  'Cher',
#  'Corrèze',
#  "Côte-d'Or",
#  "Côtes-d'Armor",
#  'Creuse',
#  'Dordogne',
#  'Doubs',
#  'Drôme',
#  'Eure',
#  'Eure-et-Loir',
#  'Finistère',
#  'Corse-du-Sud',
#  'Haute-Corse',
#  'Gard',
#  'Haute-Garonne',
#  'Gers',
#  'Gironde',
#  'Hérault',
#  'Ille-et-Vilaine',
#  'Indre',
#  'Indre-et-Loire',
#  'Isère',
#  'Jura',
#  'Landes',
#  'Loir-et-Cher',
#  'Loire',
#  'Haute-Loire',
#  'Loire-Atlantique',
#  'Loiret',
#  'Lot',
#  'Lot-et-Garonne',
#  'Lozère',
#  'Maine-et-Loire',
#  'Manche',
#  'Marne',
#  'Haute-Marne',
#  'Mayenne',
#  'Meurthe-et-Moselle',
#  'Meuse',
#  'Morbihan',
#  'Moselle',
#  'Nièvre',
#  'Nord',
#  'Oise',
#  'Orne',
#  'Pas-de-Calais',
#  'Puy-de-Dôme',
#  'Pyrénées-Atlantiques',
#  'Hautes-Pyrénées',
#  'Pyrénées-Orientales',
#  'Bas-Rhin',
#  'Haut-Rhin',
#  'Rhône',
#  'Haute-Saône',
#  'Saône-et-Loire',
#  'Sarthe',
#  'Savoie',
#  'Haute-Savoie',
#  'Paris',
#  'Seine-Maritime',
#  'Seine-et-Marne',
#  'Yvelines',
#  'Deux-Sèvres',
#  'Somme',
#  'Tarn',
#  'Tarn-et-Garonne',
#  'Var',
#  'Vaucluse',
#  'Vendée',
#  'Vienne',
#  'Haute-Vienne',
#  'Vosges',
#  'Yonne',
#  'Territoire de Belfort',
#  'Essonne',
#  'Hauts-de-Seine',
#  'Seine-Saint-Denis',
#  'Val-de-Marne',
#  "Val-d'Oise",
#  'Guadeloupe',
#  'Martinique',
#  'Guyane',
#  'La Réunion',
#  'Mayotte',
#  "Collectivités d'outre-mer"]

# %% [markdown]
# ## Store databases with Pycoa

# %% [markdown]
# Save with the functions `pycoa.getrawdb()` and `pycoa.saveoutput()`

# %%
#for database in pycoa.listwhom():
    #pycoa.setwhom(database,reload=False)
    #pycoa.saveoutput(pandas=pycoa.getrawdb(), saveformat='csv', savename=database+"-PyCoa-DF")

# %% [markdown]
# ## List elements

# %%
whichAll = []
for database in pycoa.listwhom():
    pycoa.setwhom(database,reload=False)
    print(database)
    #print(pycoa.listwhat()) 
    for which in pycoa.listwhich():
        whichAll.append(which)
    #print("From: ", pycoa.getrawdb().iloc[0][0])
# Remove duplicates
whichAll = list(dict.fromkeys(whichAll))
# Out:
# Info of dgs stored
# last update: Thu Nov 16 16:12:04 2023
# Few information concernant the selected database :  dgs
# Available key-words, which ∈ ['tot_cases']
# Example of where :  Coimbra, Santarém, Vila Real, Évora, Vila Real  ...
# Last date data  2022-10-02
# /////////////////////////////////////////////
# Info of dpc stored
# last update: Thu Nov 16 16:12:09 2023
# Few information concernant the selected database :  dpc
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  Friuli Venezia Giulia, Piemonte, Liguria, Molise, Basilicata  ...
# Last date data  2023-11-08
# /////////////////////////////////////////////
# Info of escovid19data stored
# last update: Thu Nov 16 16:12:13 2023
# Few information concernant the selected database :  escovid19data
# Available key-words, which ∈ ['cur_hosp', 'cur_hosp_per100k', 'cur_icu', 'cur_icu_per1M', 'incidence', 'population', 'tot_cases', 'tot_cases_per100k', 'tot_deaths', 'tot_deaths_per100k', 'tot_hosp', 'tot_recovered']
# Example of where :  Lugo, Araba, Bizkaia, Huesca, León  ...
# Last date data  2023-07-02
# /////////////////////////////////////////////
# Info of europa stored
# last update: Thu Nov 16 16:12:31 2023
# Few information concernant the selected database :  europa
# Available key-words, which ∈ ['cur_hosp', 'cur_icu', 'tot_deaths', 'tot_positive']
# Example of where :  Puerto Rico, Benin, Guatemala, Poland, Somalia  ...
# Last date data  2023-05-03
# /////////////////////////////////////////////
# Info of govcy stored
# last update: Thu Nov 16 16:12:35 2023
# Few information concernant the selected database :  govcy
# Available key-words, which ∈ ['cur_hosp', 'cur_icu', 'cur_incub', 'tot_cases', 'tot_deaths', 'tot_pcr', 'tot_rat', 'tot_test']
# Example of where :  Cyprus  ...
# Last date data  2022-01-13
# /////////////////////////////////////////////
# Info of imed stored
# last update: Thu Nov 16 16:12:45 2023
# Few information concernant the selected database :  imed
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  ΦΘΙΩΤΙΔΑΣ, ΛΑΡΙΣΑΣ, ΧΑΝΙΩΝ, ΚΙΛΚΙΣ, ΓΡΕΒΕΝΩΝ  ...
# Last date data  2022-10-04
# /////////////////////////////////////////////
# Info of insee stored
# last update: Thu Nov 16 16:12:01 2023
# Few information concernant the selected database :  insee
# Available key-words, which ∈ ['tot_deaths_since_2018-01-01']
# Example of where :  Marne, Tarn-et-Garonne, Haute-Savoie, Manche, Haute-Garonne  ...
# Last date data  2024-04-15
# /////////////////////////////////////////////
# Info of jhu stored
# last update: Thu Nov 16 16:09:55 2023
# Few information concernant the selected database :  jhu
# Available key-words, which ∈ ['tot_confirmed', 'tot_deaths', 'tot_recovered']
# Example of where :  Peru, Andorra, United Arab Emirates, Mexico, Poland  ...
# Last date data  2023-03-09
# /////////////////////////////////////////////
# Info of jhu-usa stored
# last update: Thu Nov 16 16:13:00 2023
# Few information concernant the selected database :  jhu-usa
# Available key-words, which ∈ ['tot_confirmed', 'tot_deaths']
# Example of where :  Nevada, Oregon, Rhode Island, Tennessee, Alaska  ...
# Last date data  2023-03-09
# /////////////////////////////////////////////
# Info of jpnmhlw stored
# last update: Thu Nov 16 16:13:14 2023
# Few information concernant the selected database :  jpnmhlw
# Available key-words, which ∈ ['cur_cases', 'cur_cases_per_100_thousand', 'cur_deaths', 'cur_severe_cases', 'tot_cases', 'tot_deaths']
# Example of where :  Niigata, Osaka, Fukui, Gifu, Kochi  ...
# Last date data  2023-05-08
# /////////////////////////////////////////////
# Info of moh stored
# last update: Thu Nov 16 16:13:25 2023
# Few information concernant the selected database :  moh
# Available key-words, which ∈ ['beds_icu_covid', 'daily_full', 'daily_partial', 'hosp_covid', 'icu_covid', 'tot_cases', 'tot_deaths']
# Example of where :  Perlis, Sarawak, Kelantan, Pahang, Negeri Sembilan  ...
# Last date data  2023-11-11
# /////////////////////////////////////////////
# Info of mpoxgh stored
# last update: Thu Nov 16 16:13:31 2023
# Few information concernant the selected database :  mpoxgh
# Available key-words, which ∈ ['total_cases', 'total_deaths']
# Example of where :  Nepal, Canada, Turkey, Brazil, United States  ...
# Last date data  2023-11-16
# /////////////////////////////////////////////
# Info of owid stored
# last update: Thu Nov 16 16:14:05 2023
# Few information concernant the selected database :  owid
# Available key-words, which ∈ ['cur_excess_mortality', 'cur_excess_mortality_cumulative_per_million', 'cur_hosp_patients', 'cur_icu_patients', 'cur_idx_positive_rate', 'cur_reproduction_rate', 'cur_weekly_hosp_admissions', 'total_boosters', 'total_cases', 'total_cases_per_million', 'total_deaths', 'total_deaths_per_million', 'total_gdp_per_capita', 'total_people_fully_vaccinated', 'total_people_fully_vaccinated_per_hundred', 'total_people_vaccinated', 'total_people_vaccinated_per_hundred', 'total_population', 'total_tests', 'total_tests_per_thousand', 'total_vaccinations', 'total_vaccinations_per_hundred']
# Example of where :  Montenegro, Chile, Egypt, Seychelles, Saint Pierre and Miquelon  ...
# Last date data  2023-11-15
# /////////////////////////////////////////////
# Info of phe stored
# last update: Thu Nov 16 16:16:47 2023
# Few information concernant the selected database :  phe
# Available key-words, which ∈ ['lineageB.1.617.2', 'tot_cases', 'tot_deaths', 'tot_tests', 'tot_vacc1', 'tot_vacc2']
# Example of where :  Broxbourne, Leicester, Nuneaton and Bedworth, Hastings, Broadland  ...
# Last date data  2023-11-08
# /////////////////////////////////////////////
# Info of risklayer stored
# last update: Thu Nov 16 16:17:15 2023
# Few information concernant the selected database :  risklayer
# Available key-words, which ∈ ['tot_incidence', 'tot_positive']
# Example of where :  Pernik, Pomurska, Olomoucký, Chişinău, Zagrebačka  ...
# Last date data  2023-05-09
# /////////////////////////////////////////////
# Info of rki stored
# last update: Thu Nov 16 16:17:31 2023
# Few information concernant the selected database :  rki
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  Hersfeld-Rotenburg, Regionalverband Saarbrücken, Borken, Stendal, Ludwigslust-Parchim  ...
# Last date data  2023-01-26
# /////////////////////////////////////////////
# Info of sciensano stored
# last update: Thu Nov 16 16:17:37 2023
# Few information concernant the selected database :  sciensano
# Available key-words, which ∈ ['cur_confirmed', 'cur_reporting', 'tot_hosp', 'tot_icu']
# Example of where :  Limburg, Luxembourg, Luxembourg, VlaamsBrabant, OostVlaanderen  ...
# Last date data  2023-06-27
# /////////////////////////////////////////////
# Info of spf stored
# last update: Thu Nov 16 16:18:21 2023
# Few information concernant the selected database :  spf
# Available key-words, which ∈ ['cur_hosp', 'cur_idx_R', 'cur_idx_tx_incid', 'cur_idx_tx_occupation_sae', 'cur_nb_A0', 'cur_nb_A1', 'cur_nb_C0', 'cur_nb_C1', 'cur_nbre_pass_corona', 'cur_rea', 'cur_tx_A1', 'cur_tx_C1', 'cur_tx_pos', 'incid_dchosp', 'incid_hosp', 'incid_rad', 'incid_rea', 'tot_P', 'tot_T', 'tot_dchosp', 'tot_rad', 'tot_vacc1', 'tot_vacc2_rappel', 'tot_vacc_complet', 'tot_vacc_rappel']
# Example of where :  Collectivités d'outre-mer, Ariège, Bas-Rhin, Landes, Somme  ...
# Last date data  2023-11-14
# /////////////////////////////////////////////
# Info of spfnational stored
# last update: Thu Nov 16 16:18:25 2023
# Few information concernant the selected database :  spfnational
# Available key-words, which ∈ ['cur_cas', 'cur_hospitalises', 'cur_reanimation', 'cur_tx_pos', 'tot_dc', 'tot_dc_esms', 'tot_dc_hosp']
# Example of where :  France  ...
# Last date data  2023-06-30
# /////////////////////////////////////////////

# %% [markdown]
# ## Metadata

# %%
for database in pycoa.listwhom():
    pycoa.setwhom(database,reload=False)
    print(database)
    print(pycoa.getkeywordinfo())
    #pycoa.saveoutput(pandas=pycoa.getrawdb(), saveformat='csv', savename=database+"-PyCoa-DF")
# Out:
# Info of dgs stored
# last update: Thu Nov 16 16:12:04 2023
# Few information concernant the selected database :  dgs
# Available key-words, which ∈ ['tot_cases']
# Example of where :  Beja, Vila Real, Beja, Bragança, Guarda  ...
# Last date data  2022-10-02
#                                                        tot_cases
# Original name                                      confirmados_1
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/dssg-pt/covi...
# Homepage               https://github.com/dssg-pt/covid19pt-data
# /////////////////////////////////////////////
# Info of dpc stored
# last update: Thu Nov 16 16:12:09 2023
# Few information concernant the selected database :  dpc
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  Campania, Molise, Friuli Venezia Giulia, Veneto, Umbria  ...
# Last date data  2023-11-08
#                                                       tot_deaths  \
# Original name                                           deceduti
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/pcm-dpc/COVI...
# Homepage                     https://github.com/pcm-dpc/COVID-19
#
#                                                        tot_cases
# Original name                                        totale_casi
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/pcm-dpc/COVI...
# Homepage                     https://github.com/pcm-dpc/COVID-19
# /////////////////////////////////////////////
# Info of escovid19data stored
# last update: Thu Nov 16 16:12:13 2023
# Few information concernant the selected database :  escovid19data
# Available key-words, which ∈ ['cur_hosp', 'cur_hosp_per100k', 'cur_icu', 'cur_icu_per1M', 'incidence', 'population', 'tot_cases', 'tot_cases_per100k', 'tot_deaths', 'tot_deaths_per100k', 'tot_hosp', 'tot_recovered']
# Example of where :  Melilla, Zamora, Salamanca, Soria, Almería  ...
# Last date data  2023-07-02
#                                                       tot_deaths  \
# Original name                                           deceased
# Description          Cumulative deaths  (original name deceased)
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                        tot_cases  \
# Original name                              cases_accumulated_PCR
# Description    Number of new COVID-19 cases detected with PCR...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                         cur_hosp  \
# Original name                                       hospitalized
# Description            Hospitalized (original name hospitalized)
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                         tot_hosp  \
# Original name                           hospitalized_accumulated
# Description    Cumulative Hospitalized (original name hospita...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                 cur_hosp_per100k  \
# Original name                            hospitalized_per_100000
# Description    Hosp per 100,000 inhabitants, (original name h...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                          cur_icu  \
# Original name                                     intensive_care
# Description    UCI, intensive care patient, (original name in...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                    tot_recovered  \
# Original name                                          recovered
# Description                  Recovered (original name recovered)
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                tot_cases_per100k  \
# Original name                                  cases_per_cienmil
# Description    Cumulative cases per 100,000 inhabitants (orig...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                    cur_icu_per1M  \
# Original name                         intensive_care_per_1000000
# Description    Intensive care per 1000,000 inhabitants (origi...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                               tot_deaths_per100k  \
# Original name                               deceassed_per_100000
# Description    Cumulative deaths per 100,000 inhabitants (ori...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                        incidence  \
# Original name                                               ia14
# Description    Cases in 14 days by 100,000 inhabitants (origi...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
#
#                                                       population
# Original name                                          poblacion
# Description    Inhabitants of the province (orignal name pobl...
# URL            https://raw.githubusercontent.com/montera34/es...
# Homepage              https://github.com/montera34/escovid19data
# /////////////////////////////////////////////
# Info of europa stored
# last update: Thu Nov 16 16:12:31 2023
# Few information concernant the selected database :  europa
# Available key-words, which ∈ ['cur_hosp', 'cur_icu', 'tot_deaths', 'tot_positive']
# Example of where :  Northern Mariana Islands, Ukraine, Guernsey, Luxembourg, Saint Pierre and Miquelon  ...
# Last date data  2023-05-03
#                                                       tot_deaths  \
# Original name                                 CumulativeDeceased
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/ec-jrc/COVID...
# Homepage       https://github.com/ec-jrc/COVID-19/tree/master...
#
#                                                     tot_positive  \
# Original name                                 CumulativePositive
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/ec-jrc/COVID...
# Homepage       https://github.com/ec-jrc/COVID-19/tree/master...
#
#                                                         cur_hosp  \
# Original name                                       Hospitalized
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/ec-jrc/COVID...
# Homepage       https://github.com/ec-jrc/COVID-19/tree/master...
#
#                                                          cur_icu
# Original name                                      IntensiveCare
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/ec-jrc/COVID...
# Homepage       https://github.com/ec-jrc/COVID-19/tree/master...
# /////////////////////////////////////////////
# Info of govcy stored
# last update: Thu Nov 16 16:12:35 2023
# Few information concernant the selected database :  govcy
# Available key-words, which ∈ ['cur_hosp', 'cur_icu', 'cur_incub', 'tot_cases', 'tot_deaths', 'tot_pcr', 'tot_rat', 'tot_test']
# Example of where :  Cyprus  ...
# Last date data  2022-01-13
#                                                       tot_deaths  \
# Original name                                       total deaths
# Description    total deaths attributed to Covid-19 disease (t...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                        tot_cases  \
# Original name                                        total cases
# Description        total number of confirmed cases (total cases)
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                         cur_hosp  \
# Original name                                 Hospitalised Cases
# Description    number of patients with covid-19 hospitalized ...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                          cur_icu  \
# Original name                                      Cases In ICUs
# Description    number of patients with covid-19 admitted to I...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                        cur_incub  \
# Original name                                    Incubated Cases
# Description    number of patients with covid-19 admitted to I...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                          tot_pcr  \
# Original name                                    total PCR tests
# Description    extract from PCR_daily tests performedtotal nu...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                          tot_rat  \
# Original name                                     total RA tests
# Description    total number of rapid antigen (RAT) tests perf...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
#
#                                                         tot_test
# Original name                                        total tests
# Description    total numbers of PCR and RA tests performed (t...
# URL            https://www.data.gov.cy/sites/default/files/CY...
# Homepage           https://www.data.gov.cy/node/4617?language=en
# /////////////////////////////////////////////
# Info of imed stored
# last update: Thu Nov 16 16:12:45 2023
# Few information concernant the selected database :  imed
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  ΗΜΑΘΙΑΣ, ΕΥΡΥΤΑΝΙΑΣ, ΑΡΓΟΛΙΔΑΣ, ΧΑΛΚΙΔΙΚΗΣ, ΔΡΑΜΑΣ  ...
# Last date data  2022-10-04
#                                                       tot_deaths  \
# Original name                                             deaths
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/iMEdD-Lab/op...
# Homepage       https://github.com/iMEdD-Lab/open-data/tree/ma...
#
#                                                        tot_cases
# Original name                                              cases
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/iMEdD-Lab/op...
# Homepage       https://github.com/iMEdD-Lab/open-data/tree/ma...
# /////////////////////////////////////////////
# Info of insee stored
# last update: Thu Nov 16 16:12:01 2023
# Few information concernant the selected database :  insee
# Available key-words, which ∈ ['tot_deaths_since_2018-01-01']
# Example of where :  Vosges, Pas-de-Calais, Val-de-Marne, Haute-Saône, Seine-et-Marne  ...
# Last date data  2024-04-15
#                                      tot_deaths_since_2018-01-01
# Original name                             daily_number_of_deaths
# Description    tot deaths number_of_deaths integrated since 2...
# URL            https://www.data.gouv.fr/fr/datasets/fichier-d...
# Homepage
# /////////////////////////////////////////////
# Info of jhu stored
# last update: Thu Nov 16 16:09:55 2023
# Few information concernant the selected database :  jhu
# Available key-words, which ∈ ['tot_confirmed', 'tot_deaths', 'tot_recovered']
# Example of where :  Palau, Hungary, Bangladesh, Ukraine, Papua New Guinea  ...
# Last date data  2023-03-09
#                                                       tot_deaths  \
# Original name                                             deaths
# Description    counts include confirmed and probable (where r...
# URL            https://raw.githubusercontent.com/CSSEGISandDa...
# Homepage              https://github.com/CSSEGISandData/COVID-19
#
#                                                    tot_confirmed  \
# Original name                                          confirmed
# Description    counts include confirmed and probable (where r...
# URL            https://raw.githubusercontent.com/CSSEGISandDa...
# Homepage              https://github.com/CSSEGISandData/COVID-19
#
#                                                    tot_recovered
# Original name                                          recovered
# Description    cases are estimates based on local media repor...
# URL            https://raw.githubusercontent.com/CSSEGISandDa...
# Homepage              https://github.com/CSSEGISandData/COVID-19
# /////////////////////////////////////////////
# Info of jhu-usa stored
# last update: Thu Nov 16 16:13:00 2023
# Few information concernant the selected database :  jhu-usa
# Available key-words, which ∈ ['tot_confirmed', 'tot_deaths']
# Example of where :  Georgia, Michigan, New Hampshire, Kentucky, New York  ...
# Last date data  2023-03-09
#                                                       tot_deaths  \
# Original name                                             deaths
# Description    counts include confirmed and probable (where r...
# URL            https://raw.githubusercontent.com/CSSEGISandDa...
# Homepage              https://github.com/CSSEGISandData/COVID-19
#
#                                                    tot_confirmed
# Original name                                          confirmed
# Description    counts include confirmed and probable (where r...
# URL            https://raw.githubusercontent.com/CSSEGISandDa...
# Homepage              https://github.com/CSSEGISandData/COVID-19
# /////////////////////////////////////////////
# Info of jpnmhlw stored
# last update: Thu Nov 16 16:13:14 2023
# Few information concernant the selected database :  jpnmhlw
# Available key-words, which ∈ ['cur_cases', 'cur_cases_per_100_thousand', 'cur_deaths', 'cur_severe_cases', 'tot_cases', 'tot_deaths']
# Example of where :  Kyoto, Gunma, Saga, Niigata, Akita  ...
# Last date data  2023-05-08
#                                                       tot_deaths  \
# Original name                            deaths_cumulative_daily
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/dea...
# Homepage                          https://covid19.mhlw.go.jp/en/
#
#                                                        cur_cases  \
# Original name                        newly_confirmed_cases_daily
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/new...
# Homepage                          https://covid19.mhlw.go.jp/en/
#
#                                       cur_cases_per_100_thousand  \
# Original name  newly_confirmed_cases_per_100_thousand_populat...
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/new...
# Homepage                          https://covid19.mhlw.go.jp/en/
#
#                                                        tot_cases  \
# Original name                   confirmed_cases_cumulative_daily
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/con...
# Homepage                          https://covid19.mhlw.go.jp/en/
#
#                                                 cur_severe_cases  \
# Original name                                 severe_cases_daily
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/sev...
# Homepage                          https://covid19.mhlw.go.jp/en/
#
#                                                       cur_deaths
# Original name                             number_of_deaths_daily
# Description                                               FILLIT
# URL            https://covid19.mhlw.go.jp/public/opendata/num...
# Homepage                          https://covid19.mhlw.go.jp/en/
# /////////////////////////////////////////////
# Info of moh stored
# last update: Thu Nov 16 16:13:25 2023
# Few information concernant the selected database :  moh
# Available key-words, which ∈ ['beds_icu_covid', 'daily_full', 'daily_partial', 'hosp_covid', 'icu_covid', 'tot_cases', 'tot_deaths']
# Example of where :  Melaka, Melaka, Sabah, Perlis, Wilayah Persekutuan Labuan  ...
# Last date data  2023-11-11
#                                                       tot_deaths  \
# Original name                                         deaths_new
# Description                        from original data deaths_new
# URL            https://raw.githubusercontent.com/MoH-Malaysia...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                        tot_cases  \
# Original name                                          cases_new
# Description                         from original data cases_new
# URL            https://raw.githubusercontent.com/MoH-Malaysia...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                       hosp_covid  \
# Original name                                         hosp_covid
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/MoH-Malaysia...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                        icu_covid  \
# Original name                                          icu_covid
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/MoH-Malaysia...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                   beds_icu_covid  \
# Original name                                     beds_icu_covid
# Description                                       beds_icu_covid
# URL            https://raw.githubusercontent.com/MoH-Malaysia...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                    daily_partial  \
# Original name                                      daily_partial
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/CITF-Malaysi...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
#
#                                                       daily_full
# Original name                                         daily_full
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/CITF-Malaysi...
# Homepage          https://github.com/MoH-Malaysia/covid19-public
# /////////////////////////////////////////////
# Info of mpoxgh stored
# last update: Thu Nov 16 16:13:31 2023
# Few information concernant the selected database :  mpoxgh
# Available key-words, which ∈ ['total_cases', 'total_deaths']
# Example of where :  Slovenia, Liberia, El Salvador, Andorra, Montenegro  ...
# Last date data  2023-11-16
#                                                     total_deaths  \
# Original name                                  total death cases
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/owid/monkeyp...
# Homepage                       https://github.com/owid/monkeypox
#
#                                                      total_cases
# Original name                              total confirmed cases
# Description                                               FILLIT
# URL            https://raw.githubusercontent.com/owid/monkeyp...
# Homepage                       https://github.com/owid/monkeypox
# /////////////////////////////////////////////
# Info of owid stored
# last update: Thu Nov 16 16:14:05 2023
# Few information concernant the selected database :  owid
# Available key-words, which ∈ ['cur_excess_mortality', 'cur_excess_mortality_cumulative_per_million', 'cur_hosp_patients', 'cur_icu_patients', 'cur_idx_positive_rate', 'cur_reproduction_rate', 'cur_weekly_hosp_admissions', 'total_boosters', 'total_cases', 'total_cases_per_million', 'total_deaths', 'total_deaths_per_million', 'total_gdp_per_capita', 'total_people_fully_vaccinated', 'total_people_fully_vaccinated_per_hundred', 'total_people_vaccinated', 'total_people_vaccinated_per_hundred', 'total_population', 'total_tests', 'total_tests_per_thousand', 'total_vaccinations', 'total_vaccinations_per_hundred']
# Example of where :  Zimbabwe, Libya, Uruguay, Mauritius, Greece  ...
# Last date data  2023-11-15
#                                                     total_deaths  \
# Original name                                       total_deaths
# Description                  Total deaths attributed to COVID-19
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                      total_cases  \
# Original name                                        total_cases
# Description                    Total confirmed cases of COVID-19
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                      total_tests  \
# Original name                                        total_tests
# Description                             Total tests for COVID-19
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                         total_tests_per_thousand  \
# Original name                           total_tests_per_thousand
# Description                Total tests for COVID-19 per thousand
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                               total_vaccinations  \
# Original name                                 total_vaccinations
# Description    Total number of COVID-19 vaccination doses adm...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                 total_population  \
# Original name                                         population
# Description                  total population of a given country
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                        total_people_fully_vaccinated_per_hundred  \
# Original name                people_fully_vaccinated_per_hundred
# Description    Total number of people who received all doses ...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                   total_boosters  \
# Original name                                     total_boosters
# Description    Total number of COVID-19 vaccination booster d...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                          total_people_vaccinated  \
# Original name                                  people_vaccinated
# Description    Total number of people who received at least o...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                    total_people_fully_vaccinated  ...  \
# Original name                            people_fully_vaccinated  ...
# Description    total_people_fully_vaccinated (original name p...  ...
# URL            https://raw.githubusercontent.com/owid/covid-1...  ...
# Homepage                                 https://github.com/owid  ...
#
#                                         total_deaths_per_million  \
# Original name                           total_deaths_per_million
# Description    Total deaths attributed to COVID-19 per 1,000,...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                   total_vaccinations_per_hundred  \
# Original name                     total_vaccinations_per_hundred
# Description    COVID19 vaccine doses administered per 100 people
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                            cur_reproduction_rate  \
# Original name                                  reproduction_rate
# Description    cur_reproduction_rate (original name reproduct...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                 cur_icu_patients  \
# Original name                                       icu_patients
# Description    cur_icu_patients (orignal name icu_patients): ...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                                cur_hosp_patients  \
# Original name                                      hosp_patients
# Description    cur_hosp_patients (original name hosp_patients...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                       cur_weekly_hosp_admissions  \
# Original name                             weekly_hosp_admissions
# Description    cur_weekly_hosp_admissions (original name week...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                            cur_idx_positive_rate  \
# Original name                                      positive_rate
# Description    cur_idx_positive_rate (original name positive_...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                             total_gdp_per_capita  \
# Original name                                     gdp_per_capita
# Description    Gross domestic product at purchasing power par...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                                             cur_excess_mortality  \
# Original name                                   excess_mortality
# Description    original name excess_mortality. Percentage dif...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
#                      cur_excess_mortality_cumulative_per_million
# Original name            excess_mortality_cumulative_per_million
# Description    cur_excess_mortality_cumulative_per_million:or...
# URL            https://raw.githubusercontent.com/owid/covid-1...
# Homepage                                 https://github.com/owid
#
# [4 rows x 22 columns]
# /////////////////////////////////////////////
# Info of phe stored
# last update: Thu Nov 16 16:16:47 2023
# Few information concernant the selected database :  phe
# Available key-words, which ∈ ['lineageB.1.617.2', 'tot_cases', 'tot_deaths', 'tot_tests', 'tot_vacc1', 'tot_vacc2']
# Example of where :  Liverpool, Kensington and Chelsea, Enfield, North East Lincolnshire, Newark and Sherwood  ...
# Last date data  2023-11-08
#                                                       tot_deaths  \
# Original name                         cumDeaths28DaysByDeathDate
# Description                              Total number of deaths
# URL            https://api.coronavirus.data.gov.uk/v2/data?ar...
# Homepage        https://coronavirus.data.gov.uk/details/download
#
#                                                        tot_cases  \
# Original name                             cumCasesBySpecimenDate
# Description                                Total number of cases
# URL            https://api.coronavirus.data.gov.uk/v2/data?ar...
# Homepage        https://coronavirus.data.gov.uk/details/download
#
#                                                        tot_tests  \
# Original name                          cumLFDTestsBySpecimenDate
# Description                                Total number of tests
# URL            https://api.coronavirus.data.gov.uk/v2/data?ar...
# Homepage        https://coronavirus.data.gov.uk/details/download
#
#                                                        tot_vacc1  \
# Original name      cumPeopleVaccinatedFirstDoseByVaccinationDate
# Description                                               FILLIT
# URL            https://api.coronavirus.data.gov.uk/v2/data?ar...
# Homepage        https://coronavirus.data.gov.uk/details/download
#
#                                                        tot_vacc2  \
# Original name     cumPeopleVaccinatedSecondDoseByVaccinationDate
# Description                                               FILLIT
# URL            https://api.coronavirus.data.gov.uk/v2/data?ar...
# Homepage        https://coronavirus.data.gov.uk/details/download
#
#                                                 lineageB.1.617.2
# Original name                                              Count
# Description                                               FILLIT
# URL            https://covid-surveillance-data.cog.sanger.ac....
# Homepage        https://coronavirus.data.gov.uk/details/download
# /////////////////////////////////////////////
# Info of risklayer stored
# last update: Thu Nov 16 16:17:15 2023
# Few information concernant the selected database :  risklayer
# Available key-words, which ∈ ['tot_incidence', 'tot_positive']
# Example of where :  Västra Götaland, Novgorod, Hercegovačko-neretvanski, Stara Zagora, Rīga  ...
# Last date data  2023-05-09
#                                                     tot_positive  \
# Original name                                 CumulativePositive
# Description                                               FILLIT
# URL            https://docs.google.com/spreadsheets/d/e/2PACX...
# Homepage       https://www.risklayer-explorer.com/event/100/d...
#
#                                                    tot_incidence
# Original name                                IncidenceCumulative
# Description                                               FILLIT
# URL            https://docs.google.com/spreadsheets/d/e/2PACX...
# Homepage       https://www.risklayer-explorer.com/event/100/d...
# /////////////////////////////////////////////
# Info of rki stored
# last update: Thu Nov 16 16:17:31 2023
# Few information concernant the selected database :  rki
# Available key-words, which ∈ ['tot_cases', 'tot_deaths']
# Example of where :  Rhein-Lahn-Kreis, Olpe, Altenburger Land, Rhein-Lahn-Kreis, Pirmasens  ...
# Last date data  2023-01-26
#                                                       tot_deaths  \
# Original name                                         tot_deaths
# Description                                               FILLIT
# URL            https://github.com/jgehrcke/covid-19-germany-g...
# Homepage        https://github.com/jgehrcke/covid-19-germany-gae
#
#                                                        tot_cases
# Original name                                          tot_cases
# Description                                               FILLIT
# URL            https://github.com/jgehrcke/covid-19-germany-g...
# Homepage        https://github.com/jgehrcke/covid-19-germany-gae
# /////////////////////////////////////////////
# Info of sciensano stored
# last update: Thu Nov 16 16:17:37 2023
# Few information concernant the selected database :  sciensano
# Available key-words, which ∈ ['cur_confirmed', 'cur_reporting', 'tot_hosp', 'tot_icu']
# Example of where :  Luxembourg, Namur, Brussels, Antwerpen, OostVlaanderen  ...
# Last date data  2023-06-27
#                                                         tot_hosp  \
# Original name                                           TOTAL_IN
# Description    Total number of lab-confirmed hospitalized COV...
# URL            https://epistat.sciensano.be/Data/COVID19BE_HO...
# Homepage                       https://epistat.wiv-isp.be/covid/
#
#                                                          tot_icu  \
# Original name                                       TOTAL_IN_ICU
# Description    Total number of lab-confirmed hospitalized COV...
# URL            https://epistat.sciensano.be/Data/COVID19BE_HO...
# Homepage                       https://epistat.wiv-isp.be/covid/
#
#                                                    cur_reporting  \
# Original name                                       NR_REPORTING
# Description                        Number of hospitals reporting
# URL            https://epistat.sciensano.be/Data/COVID19BE_HO...
# Homepage                       https://epistat.wiv-isp.be/covid/
#
#                                                    cur_confirmed
# Original name                                             NEW_IN
# Description    Number of new lab-confirmed COVID-19 patients ...
# URL            https://epistat.sciensano.be/Data/COVID19BE_HO...
# Homepage                       https://epistat.wiv-isp.be/covid/
# /////////////////////////////////////////////
# Info of spf stored
# last update: Thu Nov 16 16:18:21 2023
# Few information concernant the selected database :  spf
# Available key-words, which ∈ ['cur_hosp', 'cur_idx_R', 'cur_idx_tx_incid', 'cur_idx_tx_occupation_sae', 'cur_nb_A0', 'cur_nb_A1', 'cur_nb_C0', 'cur_nb_C1', 'cur_nbre_pass_corona', 'cur_rea', 'cur_tx_A1', 'cur_tx_C1', 'cur_tx_pos', 'incid_dchosp', 'incid_hosp', 'incid_rad', 'incid_rea', 'tot_P', 'tot_T', 'tot_dchosp', 'tot_rad', 'tot_vacc1', 'tot_vacc2_rappel', 'tot_vacc_complet', 'tot_vacc_rappel']
# Example of where :  Paris, Côte-d'Or, Loiret, Hérault, Loire  ...
# Last date data  2023-11-14
#                                                       tot_dchosp  \
# Original name                                             dchosp
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                            tot_P  \
# Original name                                                  P
# Description                       Nombre total de tests positifs
# URL            https://www.data.gouv.fr/fr/datasets/r/ca49048...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                            tot_T  \
# Original name                                                  T
# Description                       Nombre total de tests réalisés
# URL            https://www.data.gouv.fr/fr/datasets/r/ca49048...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                         cur_hosp  \
# Original name                                               hosp
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                          tot_rad  \
# Original name                                                rad
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                          cur_rea  \
# Original name                                                rea
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                 cur_idx_tx_incid  \
# Original name                                           tx_incid
# Description    Taux d'incidence (activité épidémique : Le tau...
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                       incid_hosp  \
# Original name                                         incid_hosp
# Description              Nombre total de personnes hospitalisées
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        incid_rea  \
# Original name                                          incid_rea
# Description             Nombre total d'admissions en réanimation
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        incid_rad  ...  \
# Original name                                          incid_rad  ...
# Description                  Nombre total de  retours à domicile  ...
# URL            https://www.data.gouv.fr/fr/datasets/r/5c4e145...  ...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...  ...
#
#                                                 tot_vacc_complet  \
# Original name                                      n_cum_complet
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/83cbbdb...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-r...
#
#                                                  tot_vacc_rappel  \
# Original name                                       n_cum_rappel
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/83cbbdb...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-r...
#
#                                                 tot_vacc2_rappel  \
# Original name                                     n_cum_2_rappel
# Description                                               FILLIT
# URL            https://www.data.gouv.fr/fr/datasets/r/83cbbdb...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-r...
#
#                                                        cur_nb_A0  \
# Original name                                              nb_A0
# Description    Nombre des tests positifs pour lesquels la rec...
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        cur_nb_A1  \
# Original name                                              nb_A1
# Description    Nombre des tests positifs pour lesquels la rec...
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        cur_tx_A1  \
# Original name                                              tx_A1
# Description              Taux de présence mutation A (A = E484K)
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        cur_nb_C0  \
# Original name                                              nb_C0
# Description    Nombre des tests positifs pour lesquels la rec...
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        cur_nb_C1  \
# Original name                                              nb_C1
# Description    Nombre des tests positifs pour lesquels la rec...
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                                        cur_tx_C1  \
# Original name                                              tx_C1
# Description              Taux de présence mutation C (C = L452R)
# URL            https://www.data.gouv.fr/fr/datasets/r/bc318bc...
# Homepage       https://www.data.gouv.fr/fr/datasets/donnees-d...
#
#                                             cur_nbre_pass_corona
# Original name                                   nbre_pass_corona
# Description    Nombre de passages aux urgences pour suspicion...
# URL            https://www.data.gouv.fr/en/datasets/r/eceb9fb...
# Homepage       https://www.data.gouv.fr/en/datasets/donnees-d...
#
# [4 rows x 25 columns]
# /////////////////////////////////////////////
# Info of spfnational stored
# last update: Thu Nov 16 16:18:25 2023
# Few information concernant the selected database :  spfnational
# Available key-words, which ∈ ['cur_cas', 'cur_hospitalises', 'cur_reanimation', 'cur_tx_pos', 'tot_dc', 'tot_dc_esms', 'tot_dc_hosp']
# Example of where :  France  ...
# Last date data  2023-06-30
#                                                      tot_dc_hosp  \
# Original name                                             dchosp
# Description    Cumul des décès (cumul des décès constatés à l...
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                  cur_reanimation  \
# Original name                                          incid_rea
# Description    Nombre de nouveaux patients admis en réanimati...
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                 cur_hospitalises  \
# Original name                                         incid_hosp
# Description    Nombre de nouveaux patients hospitalisés au co...
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                          cur_cas  \
# Original name                                            conf_j1
# Description    Nombre de nouveaux cas confirmés (J-1 date de ...
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                      tot_dc_esms  \
# Original name                                            esms_dc
# Description                                        Décès en ESMS
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                           tot_dc  \
# Original name                                             dc_tot
# Description                                              FILL IT
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
#
#                                                       cur_tx_pos
# Original name                                             tx_pos
# Description            Taux de positivité des tests virologiques
# URL            https://www.data.gouv.fr/fr/datasets/r/f335f9e...
# Homepage       https://www.data.gouv.fr/fr/datasets/synthese-...
# /////////////////////////////////////////////
