# %% [markdown]
# # Testing INSEE db within the `pycoa` framework

# %%
# !pwd
# Out:
# /home/beau/cernbox/Git/pycoa/coabook

# %%
import sys
sys.path.insert(1, '..')   #adapt the path for local install, if necessary. Under google colab, do not change anything
sys.path.insert(1, '..')
import coa.tools as ct
ct.set_verbose_mode(2)
import coa.covid19 as coco
from bokeh.io import show, output_notebook

# %%
output_notebook(hide_banner=True)
db,cocoplot = coco.DataBase.factory('insee')
# Out:
# Init of covid19.DataBase()
# Using locally stored data for https://data.opendatasoft.com/explore/dataset/georef-france-departement@public/download/?format=geojson&timezone=Europe/Berlin&lang=fr stored as /tmp/pycoa_data_beau/data.opendatasoft.com_3123822252
# Using locally stored data for https://fr.wikipedia.org/w/index.php?title=R%C3%A9gion_fran%C3%A7aise&oldid=177269957 stored as /tmp/pycoa_data_beau/fr.wikipedia.org_548392600
# Using locally stored data for https://github.com/coa-project/coadata/raw/main/coastore/www.insee.fr_3658796960 stored as /tmp/pycoa_data_beau/github.com_2291215763
# Init of CocoDisplay() with db=insee
# Using locally stored data for https://data.opendatasoft.com/explore/dataset/georef-france-departement@public/download/?format=geojson&timezone=Europe/Berlin&lang=fr stored as /tmp/pycoa_data_beau/data.opendatasoft.com_3123822252
# Using locally stored data for https://fr.wikipedia.org/w/index.php?title=R%C3%A9gion_fran%C3%A7aise&oldid=177269957 stored as /tmp/pycoa_data_beau/fr.wikipedia.org_548392600
# Using locally stored data for https://github.com/coa-project/coadata/raw/main/coastore/www.insee.fr_3658796960 stored as /tmp/pycoa_data_beau/github.com_2291215763
# FRA, INSEE global deaths statistics...
# Using locally stored data for https://www.data.gouv.fr/fr/datasets/fichier-des-personnes-decedees/ stored as /tmp/pycoa_data_beau/www.data.gouv.fr_3603786268
# Using locally stored data for https://www.data.gouv.fr/fr/datasets/r/ab05a355-169a-44d0-9539-02f3fcb6c5d0 stored as /tmp/pycoa_data_beau/www.data.gouv.fr_3597508866
# Using locally stored data for https://www.data.gouv.fr/fr/datasets/r/a1f09595-0e79-4300-be1a-c97964e55f05 stored as /tmp/pycoa_data_beau/www.data.gouv.fr_1023116274
# Using locally stored data for https://www.data.gouv.fr/fr/datasets/r/02acf8f5-9190-4f8e-a37c-3b34eccac833 stored as /tmp/pycoa_data_beau/www.data.gouv.fr_61488810
# Problem in a date parsing insee data for :  NGUYEN*THI NAM/                                                                 20000000099243VINH BINH                     VIET NAM                      2009062695277302
#  20030303
# Problem in a date parsing insee data for :  BEN AHMED*AHMED/                                                                10000000099350ROUADI AL HOCEINA                                           2020091359360197
#  20030826
# Problem in a date parsing insee data for :  MARTIN*ELASICE/                                                                 20000000099990                              PAYS INCONNU                  201509129730114
#  20031206
# Problem in a date parsing insee data for :  AKO*AMAFFE ROGER/                                                               10000000099326EBIMPE                        COTE D'IVOIRE                 2019061594043444
#  20030616
#         death_date location  sex  i         age  age_class  \
# 794     2019-01-04       99    3  2  149.843836          7
# 795     2019-01-05       99    1  1   70.060274          3
# 796     2019-01-06       99    1  1   42.126027          2
# 797     2019-01-07       98    1  1   90.841096          4
# 798     2019-01-07       99    3  2  147.528767          6
# ...            ...      ...  ... ..         ...        ...
# 121597  2019-12-30       92    2  1   78.493151          3
# 121598  2019-12-30       93    3  2  137.084932          6
# 121599  2019-12-30       94    4  3  226.545205         10
# 121600  2019-12-30       95    1  1   93.090411          4
# 121601  2019-12-30       97   11  9  675.630137         29
#
#         daily_number_of_deaths        date
# 794                          2  2019-01-04
# 795                          1  2019-01-05
# 796                          1  2019-01-06
# 797                          1  2019-01-07
# 798                          2  2019-01-07
# ...                        ...         ...
# 121597                       1  2019-12-30
# 121598                       2  2019-12-30
# 121599                       3  2019-12-30
# 121600                       1  2019-12-30
# 121601                       9  2019-12-30
#
# [114479 rows x 8 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/cernbox/Git/pycoa/coabook/../coa/covid19.py in __init__(self, db_name)
#     625
# --> 626                     self.return_structured_pandas(p,columns_keeped=['daily_numer_of_deaths'])
#     627             except:
#
# ~/cernbox/Git/pycoa/coabook/../coa/covid19.py in return_structured_pandas(self, mypandas, **kwargs)
#     925             columns_keeped = [x for x in mypandas.columns.values.tolist() if x not in columns_skipped + absolutlyneeded]
# --> 926         mypandas = mypandas[absolutlyneeded + columns_keeped]
#     927
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#
# KeyError: "['daily_numer_of_deaths'] not in index"
#
# During handling of the above exception, another exception occurred:
#
# CoaDbError                                Traceback (most recent call last)
# <ipython-input-3-c379527efbea> in <module>
#       1 output_notebook(hide_banner=True)
# ----> 2 db,cocoplot = coco.DataBase.factory('insee')
#
# ~/cernbox/Git/pycoa/coabook/../coa/covid19.py in factory(db_name)
#     640         This is recommended to avoid mismatch in labeled figures
#     641        '''
# --> 642        datab = DataBase(db_name)
#     643        return  datab, datab.get_display()
#     644
#
# ~/cernbox/Git/pycoa/coabook/../coa/covid19.py in __init__(self, db_name)
#     626                     self.return_structured_pandas(p,columns_keeped=['daily_numer_of_deaths'])
#     627             except:
# --> 628                 raise CoaDbError("An error occured while parsing data of "+self.get_db()+". This may be due to a data format modification. "
#     629                     "You may contact support@pycoa.fr. Thanks.")
#     630             # some info
#
# CoaDbError: An error occured while parsing data of insee. This may be due to a data format modification. You may contact support@pycoa.fr. Thanks.

# %%
import pandas as pd
pd.read_json('https://presidentielle2022.conseil-constitutionnel.fr/telechargement/parrainagestotal.json').groupby('Candidat')['Candidat'].count().sort_values()
# Out:
# Candidat
# ROCCA Martin                    1
# MARECHAL Philippe Célestin      1
# SCHOVANEC Josef                 1
# CAU Marie                       1
# MAZUEL Philippe                 1
# BARNIER Michel                  1
# BEKAERT Corinne                 1
# SMATI  Rafik                    2
# CHICHE Arnaud                   4
# MARTINEZ Antoine                5
# EGGER Clara                     6
# MIGUET Nicolas                  9
# KOENIG Gaspard                 23
# KUZMANOVIC Georges             25
# TAUBIRA Christiane             36
# THOUY Hélène                   48
# KAZIB Anasse                   84
# POUTOU Philippe               127
# LE PEN Marine                 139
# ZEMMOUR Éric                  149
# ASSELINEAU François           171
# MÉLENCHON Jean-Luc            224
# DUPONT-AIGNAN Nicolas         232
# JADOT Yannick                 268
# LASSALLE Jean                 316
# ROUSSEL Fabien                326
# ARTHAUD Nathalie              368
# HIDALGO Anne                  652
# MACRON Emmanuel               926
# PÉCRESSE Valérie              939
# Name: Candidat, dtype: int64
